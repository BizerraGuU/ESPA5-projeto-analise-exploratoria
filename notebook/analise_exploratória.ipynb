# %%
# Bibliotecas

import numpy as np  # Computação numérica - arrays e matemática
import pandas as pd  # Manipulação de dados - tabelas e análise
import matplotlib.pyplot as plt  # Gráficos básicos - histogramas, scatter plots
import seaborn as sns  # Gráficos estatísticos avançados - mais bonitos e informativos
import scipy.stats as stats  # Estatística avançada - testes, distribuições probabilísticas
from scipy.stats import norm, t, binom, poisson  # Distribuições probabilísticas específicas

# %% [markdown]
# # Estatística descritiva

# %% [markdown]
# # Probabilidade

# %% [markdown]
# # Inferência
